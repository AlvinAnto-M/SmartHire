# %% [markdown]
# # Notebook 01: Exploring Text Embeddings for Job Matching
# This notebook demonstrates how candidate resume text and job descriptions are converted into dense vector representations using text embeddings.

# %%
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv

load_dotenv("../.env")
jobs_df = pd.read_csv("../data/jobs/jobs.csv")
print(f"Loaded {len(jobs_df)} jobs.")
jobs_df.head(3)

# %%
# Inspecting semantic similarity between roles
from sklearn.metrics.pairwise import cosine_similarity
print("Sample roles:", jobs_df["job_title"].tolist())
